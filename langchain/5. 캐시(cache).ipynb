# %%
from dotenv import load_dotenv
import os

load_dotenv()
print(os.environ.get('OPENAI_API_KEY')[:20])

# v1.2.6
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.globals import set_llm_cache
from langchain_core.caches import InMemoryCache
# Out:
# sk-proj-2t69LdIulCeS

# %%
# 모든 llm의 response가 메모리에 저장됨
in_memory_cache = InMemoryCache()
set_llm_cache(in_memory_cache)

# %%
chat = ChatOpenAI(temperature=0.1)

# %%
import time
from datetime import timedelta

# %%
def check_laptime(message):

    start_time = time.time()
    response = chat.invoke(message)
    end_time = time.time()

    elapsed_time = end_time - start_time
    print(f"경과 시간: {str(timedelta(seconds=elapsed_time))}")
    print(f"글자 수: {len(response.content)}")
    print(response.content)

# %%
check_laptime("피자를 만드는 방법에 대해서 알려줘!")
# Out:
# 경과 시간: 0:00:03.629167
# 글자 수: 391
# 피자를 만드는 방법은 다음과 같습니다:
#
# 1. 준비물: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일, 토마토 소스, 치즈, 토핑 재료(페퍼로니, 양파, 피망 등)
#
# 2. 반죽 만들기: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일을 섞어 부드러운 반죽을 만든다. 이후 1시간 정도 발효시켜준다.
#
# 3. 반죽을 밀가루로 뭉쳐서 동그랗게 만들고, 밀가루를 뿌려서 밀가루로 뭉친 반죽을 눌러서 동그랗게 펴준다.
#
# 4. 피자 팬에 반죽을 올리고, 토마토 소스를 발라준다.
#
# 5. 치즈와 토핑 재료를 올려주고, 200도로 예열된 오븐에 15-20분간 굽는다.
#
# 6. 완성된 피자를 잘라서 내놓고, 맛있게 즐기면 된다.
#
# 이렇게 하면 집에서 간단하게 맛있는 피자를 만들 수 있습니다. 맛있게 즐기세요!

# %%
check_laptime("치킨은 어떻게 만들어야해?")
# Out:
# 경과 시간: 0:00:03.129656
# 글자 수: 309
# 치킨을 만들기 위해서는 먼저 신선한 닭고기를 준비해야 합니다. 닭고기를 손질하고 씻은 후, 마리네이드에 재워 맛을 내줍니다. 일반적으로는 간장, 설탕, 다진 마늘, 후추, 생강 등을 사용하여 마리네이드를 만들어 사용합니다.
#
# 마리네이드를 한 닭고기를 후라이팬에 넣고 고기가 익을 때까지 굽거나 오븐에 구워주면 됩니다. 또는 튀김옷을 입혀 튀겨서 치킨을 만들 수도 있습니다.
#
# 치킨을 만들 때는 고기가 완전히 익었는지 확인해야 하며, 골고루 익히기 위해 가끔씩 뒤집어주는 것이 좋습니다. 마지막으로는 곁들일 소스나 양념을 곁들여 맛을 더해주면 완성됩니다.

# %%
print(in_memory_cache._cache)
# Out:
# {('[{"lc": 1, "type": "constructor", "id": ["langchain", "schema", "messages", "HumanMessage"], "kwargs": {"content": "\\ud53c\\uc790\\ub97c \\ub9cc\\ub4dc\\ub294 \\ubc29\\ubc95\\uc5d0 \\ub300\\ud574\\uc11c \\uc54c\\ub824\\uc918!", "type": "human"}}]', '{"id": ["langchain", "chat_models", "openai", "ChatOpenAI"], "kwargs": {"model_name": "gpt-3.5-turbo", "openai_api_key": {"id": ["OPENAI_API_KEY"], "lc": 1, "type": "secret"}, "openai_proxy": null, "output_version": null, "stream_usage": true, "temperature": 0.1}, "lc": 1, "name": "ChatOpenAI", "type": "constructor"}---[(\'stop\', None)]'): [ChatGeneration(text='피자를 만드는 방법은 다음과 같습니다:\n\n1. 준비물: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일, 토마토 소스, 치즈, 토핑 재료(페퍼로니, 양파, 피망 등)\n\n2. 반죽 만들기: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일을 섞어 부드러운 반죽을 만든다. 이후 1시간 정도 발효시켜준다.\n\n3. 반죽을 밀가루로 뭉쳐서 동그랗게 만들고, 밀가루를 뿌려서 밀가루로 뭉친 반죽을 눌러서 동그랗게 펴준다.\n\n4. 피자 팬에 반죽을 올리고, 토마토 소스를 발라준다.\n\n5. 치즈와 토핑 재료를 올려주고, 200도로 예열된 오븐에 15-20분간 굽는다.\n\n6. 완성된 피자를 잘라서 내놓고, 맛있게 즐기면 된다.\n\n이렇게 하면 집에서 간단하게 맛있는 피자를 만들 수 있습니다. 맛있게 즐기세요!', generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content='피자를 만드는 방법은 다음과 같습니다:\n\n1. 준비물: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일, 토마토 소스, 치즈, 토핑 재료(페퍼로니, 양파, 피망 등)\n\n2. 반죽 만들기: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일을 섞어 부드러운 반죽을 만든다. 이후 1시간 정도 발효시켜준다.\n\n3. 반죽을 밀가루로 뭉쳐서 동그랗게 만들고, 밀가루를 뿌려서 밀가루로 뭉친 반죽을 눌러서 동그랗게 펴준다.\n\n4. 피자 팬에 반죽을 올리고, 토마토 소스를 발라준다.\n\n5. 치즈와 토핑 재료를 올려주고, 200도로 예열된 오븐에 15-20분간 굽는다.\n\n6. 완성된 피자를 잘라서 내놓고, 맛있게 즐기면 된다.\n\n이렇게 하면 집에서 간단하게 맛있는 피자를 만들 수 있습니다. 맛있게 즐기세요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 419, 'prompt_tokens': 28, 'total_tokens': 447, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfIjiYqu63VqLmgfVM4bjceeBuGFu', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e24ea-fd20-74a0-b99e-24706b6f099d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 28, 'output_tokens': 419, 'total_tokens': 447, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}))], ('[{"lc": 1, "type": "constructor", "id": ["langchain", "schema", "messages", "HumanMessage"], "kwargs": {"content": "\\uce58\\ud0a8\\uc740 \\uc5b4\\ub5bb\\uac8c \\ub9cc\\ub4e4\\uc5b4\\uc57c\\ud574?", "type": "human"}}]', '{"id": ["langchain", "chat_models", "openai", "ChatOpenAI"], "kwargs": {"model_name": "gpt-3.5-turbo", "openai_api_key": {"id": ["OPENAI_API_KEY"], "lc": 1, "type": "secret"}, "openai_proxy": null, "output_version": null, "stream_usage": true, "temperature": 0.1}, "lc": 1, "name": "ChatOpenAI", "type": "constructor"}---[(\'stop\', None)]'): [ChatGeneration(text='치킨을 만들기 위해서는 먼저 신선한 닭고기를 준비해야 합니다. 닭고기를 손질하고 씻은 후, 마리네이드에 재워 맛을 내줍니다. 일반적으로는 간장, 설탕, 다진 마늘, 후추, 생강 등을 사용하여 마리네이드를 만들어 사용합니다.\n\n마리네이드를 한 닭고기를 후라이팬에 넣고 고기가 익을 때까지 굽거나 오븐에 구워주면 됩니다. 또는 튀김옷을 입혀 튀겨서 치킨을 만들 수도 있습니다.\n\n치킨을 만들 때는 고기가 완전히 익었는지 확인해야 하며, 골고루 익히기 위해 가끔씩 뒤집어주는 것이 좋습니다. 마지막으로는 곁들일 소스나 양념을 곁들여 맛을 더해주면 완성됩니다.', generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content='치킨을 만들기 위해서는 먼저 신선한 닭고기를 준비해야 합니다. 닭고기를 손질하고 씻은 후, 마리네이드에 재워 맛을 내줍니다. 일반적으로는 간장, 설탕, 다진 마늘, 후추, 생강 등을 사용하여 마리네이드를 만들어 사용합니다.\n\n마리네이드를 한 닭고기를 후라이팬에 넣고 고기가 익을 때까지 굽거나 오븐에 구워주면 됩니다. 또는 튀김옷을 입혀 튀겨서 치킨을 만들 수도 있습니다.\n\n치킨을 만들 때는 고기가 완전히 익었는지 확인해야 하며, 골고루 익히기 위해 가끔씩 뒤집어주는 것이 좋습니다. 마지막으로는 곁들일 소스나 양념을 곁들여 맛을 더해주면 완성됩니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 301, 'prompt_tokens': 23, 'total_tokens': 324, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache ...

# %%
for i in in_memory_cache._cache.keys():
    print(i)
# Out:
# ('[{"lc": 1, "type": "constructor", "id": ["langchain", "schema", "messages", "HumanMessage"], "kwargs": {"content": "\\ud53c\\uc790\\ub97c \\ub9cc\\ub4dc\\ub294 \\ubc29\\ubc95\\uc5d0 \\ub300\\ud574\\uc11c \\uc54c\\ub824\\uc918!", "type": "human"}}]', '{"id": ["langchain", "chat_models", "openai", "ChatOpenAI"], "kwargs": {"model_name": "gpt-3.5-turbo", "openai_api_key": {"id": ["OPENAI_API_KEY"], "lc": 1, "type": "secret"}, "openai_proxy": null, "output_version": null, "stream_usage": true, "temperature": 0.1}, "lc": 1, "name": "ChatOpenAI", "type": "constructor"}---[(\'stop\', None)]')
# ('[{"lc": 1, "type": "constructor", "id": ["langchain", "schema", "messages", "HumanMessage"], "kwargs": {"content": "\\uce58\\ud0a8\\uc740 \\uc5b4\\ub5bb\\uac8c \\ub9cc\\ub4e4\\uc5b4\\uc57c\\ud574?", "type": "human"}}]', '{"id": ["langchain", "chat_models", "openai", "ChatOpenAI"], "kwargs": {"model_name": "gpt-3.5-turbo", "openai_api_key": {"id": ["OPENAI_API_KEY"], "lc": 1, "type": "secret"}, "openai_proxy": null, "output_version": null, "stream_usage": true, "temperature": 0.1}, "lc": 1, "name": "ChatOpenAI", "type": "constructor"}---[(\'stop\', None)]')

# %%
for i in in_memory_cache._cache.values():
    print(i)
# Out:
# [ChatGeneration(text='피자를 만드는 방법은 다음과 같습니다:\n\n1. 준비물: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일, 토마토 소스, 치즈, 토핑 재료(페퍼로니, 양파, 피망 등)\n\n2. 반죽 만들기: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일을 섞어 부드러운 반죽을 만든다. 이후 1시간 정도 발효시켜준다.\n\n3. 반죽을 밀가루로 뭉쳐서 동그랗게 만들고, 밀가루를 뿌려서 밀가루로 뭉친 반죽을 눌러서 동그랗게 펴준다.\n\n4. 피자 팬에 반죽을 올리고, 토마토 소스를 발라준다.\n\n5. 치즈와 토핑 재료를 올려주고, 200도로 예열된 오븐에 15-20분간 굽는다.\n\n6. 완성된 피자를 잘라서 내놓고, 맛있게 즐기면 된다.\n\n이렇게 하면 집에서 간단하게 맛있는 피자를 만들 수 있습니다. 맛있게 즐기세요!', generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content='피자를 만드는 방법은 다음과 같습니다:\n\n1. 준비물: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일, 토마토 소스, 치즈, 토핑 재료(페퍼로니, 양파, 피망 등)\n\n2. 반죽 만들기: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일을 섞어 부드러운 반죽을 만든다. 이후 1시간 정도 발효시켜준다.\n\n3. 반죽을 밀가루로 뭉쳐서 동그랗게 만들고, 밀가루를 뿌려서 밀가루로 뭉친 반죽을 눌러서 동그랗게 펴준다.\n\n4. 피자 팬에 반죽을 올리고, 토마토 소스를 발라준다.\n\n5. 치즈와 토핑 재료를 올려주고, 200도로 예열된 오븐에 15-20분간 굽는다.\n\n6. 완성된 피자를 잘라서 내놓고, 맛있게 즐기면 된다.\n\n이렇게 하면 집에서 간단하게 맛있는 피자를 만들 수 있습니다. 맛있게 즐기세요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 419, 'prompt_tokens': 28, 'total_tokens': 447, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfIjiYqu63VqLmgfVM4bjceeBuGFu', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e24ea-fd20-74a0-b99e-24706b6f099d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 28, 'output_tokens': 419, 'total_tokens': 447, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}))]
# [ChatGeneration(text='치킨을 만들기 위해서는 먼저 신선한 닭고기를 준비해야 합니다. 닭고기를 손질하고 씻은 후, 마리네이드에 재워 맛을 내줍니다. 일반적으로는 간장, 설탕, 다진 마늘, 후추, 생강 등을 사용하여 마리네이드를 만들어 사용합니다.\n\n마리네이드를 한 닭고기를 후라이팬에 넣고 고기가 익을 때까지 굽거나 오븐에 구워주면 됩니다. 또는 튀김옷을 입혀 튀겨서 치킨을 만들 수도 있습니다.\n\n치킨을 만들 때는 고기가 완전히 익었는지 확인해야 하며, 골고루 익히기 위해 가끔씩 뒤집어주는 것이 좋습니다. 마지막으로는 곁들일 소스나 양념을 곁들여 맛을 더해주면 완성됩니다.', generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content='치킨을 만들기 위해서는 먼저 신선한 닭고기를 준비해야 합니다. 닭고기를 손질하고 씻은 후, 마리네이드에 재워 맛을 내줍니다. 일반적으로는 간장, 설탕, 다진 마늘, 후추, 생강 등을 사용하여 마리네이드를 만들어 사용합니다.\n\n마리네이드를 한 닭고기를 후라이팬에 넣고 고기가 익을 때까지 굽거나 오븐에 구워주면 됩니다. 또는 튀김옷을 입혀 튀겨서 치킨을 만들 수도 있습니다.\n\n치킨을 만들 때는 고기가 완전히 익었는지 확인해야 하며, 골고루 익히기 위해 가끔씩 뒤집어주는 것이 좋습니다. 마지막으로는 곁들일 소스나 양념을 곁들여 맛을 더해주면 완성됩니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 301, 'prompt_tokens': 23, 'total_tokens': 324, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfIjlVOb1qvBdJs91digrkRazwqT8', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e24eb-0b56-7850-a41f-c3a830b09e6c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 23, 'output_tokens': 301, 'total_tokens': 324, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}))]

# %%
# 프로그램 종료시 삭제 자동 삭제
# 캐시 삭제

in_memory_cache.clear()

# %%
in_memory_cache._cache
# Out:
# {}

# %% [markdown]
# # Debug 설정

# %%
from langchain_core.globals import set_debug

# %%
set_debug(True)

# %%
chat.invoke("랍스터는 누구의 후손이야?")
# Out:
# [llm/start] [llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: 랍스터는 누구의 후손이야?"
#   ]
# }
# [llm/end] [llm:ChatOpenAI] [1.52s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "랍스터는 게의 후손입니다.",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "랍스터는 게의 후손입니다.",
#             "additional_kwargs": {
#               "refusal": null
#             },
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 12,
#                 "prompt_tokens": 23,
#                 "total_tokens": 35,
#                 "completion_tokens_details": {
#                   "accepted_prediction_tokens": 0,
#                   "audio_tokens": 0,
#                   "reasoning_tokens": 0,
#                   "rejected_prediction_tokens": 0
#                 },
#                 "prompt_tokens_details": {
#                   "audio_tokens": 0,
#                   "cached_tokens": 0
#                 }
#               },
#               "model_provider": "openai",
#               "model_name": "gpt-3.5-turbo-0125",
#               "system_fingerprint": null,
#               "id": "chatcmpl-DfIpCTRNYET5Q3Q1En4fuCRJO3k05",
#               "service_tier": "default",
#               "finish_reason": "stop",
#               "logprobs": null
#             },
#             "type": "ai",
#             "id": "lc_run--019e24f0-2b4a-7183-85b1-38b0c0d40596-0",
#             "usage_metadata": {
#               "input_tokens": 23,
#               "output_tokens": 12,
#               "total_tokens": 35,
#               "input_token_details": {
#                 "audio": 0,
#                 "cache_read": 0
#               },
#               "output_token_details": {
#                 "audio": 0,
#                 "reasoning": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 12,
#       "prompt_tokens": 23,
#       "total_tokens": 35,
#       "completion_tokens_details": {
#         "accepted_prediction_tokens": 0,
#         "audio_tokens": 0,
#         "reasoning_tokens": 0,
#         "rejected_prediction_tokens": 0
#       },
#       "prompt_tokens_details": {
#         "audio_tokens": 0,
#         "cached_tokens": 0
#       }
#     },
#     "model_provider": "openai",
#     "model_name": "gpt-3.5-turbo-0125",
#     "system_fingerprint": null,
#     "id": "chatcmpl-DfIpCTRNYET5Q3Q1En4fuCRJO3k05",
#     "service_tier": "default"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# AIMessage(content='랍스터는 게의 후손입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 23, 'total_tokens': 35, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfIpCTRNYET5Q3Q1En4fuCRJO3k05', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e24f0-2b4a-7183-85b1-38b0c0d40596-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 23, 'output_tokens': 12, 'total_tokens': 35, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
set_debug(False)

# %%
set_llm_cache(None)
