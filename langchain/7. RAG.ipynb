# %%
from dotenv import load_dotenv
import os

load_dotenv()
print(os.environ.get('OPENAI_API_KEY')[:20])

from langchain_openai.chat_models import ChatOpenAI
from langchain_core.prompts.prompt import PromptTemplate
from langchain_core.prompts.chat import ChatPromptTemplate
# Out:
# sk-proj-2t69LdIulCeS

# %% [markdown]
# <img src='https://storage.googleapis.com/gweb-research2023-media/images/SufficientContext2_RAG.width-1250.png' />

# %%
chat = ChatOpenAI(temperature=0.1)

# %%
base_path = r"C:\back_0900_lgh\python\resource"

# %%
file_name = "chapter_one.txt"

# %%
file_path = os.path.join(base_path, file_name)

# %%
print(file_path)
# Out:
# C:\back_0900_lgh\python\resource\chapter_one.txt

# %% [markdown]
# # 1. Text Loader

# %%
from langchain_community.document_loaders.text import TextLoader

# %%
loader = TextLoader(file_path)

# %%
docs = loader.load()

# %%
# List[Document]

docs[0].page_content
# Out:
# "Part 1, Chapter 1\n\n\nPart One\n\n\n1\nIt was a bright cold day in April, and the clocks were striking thirteen. Winston Smith, his chin nuzzled into his breast in an effort to escape the vile wind, slipped quickly through the glass doors of Victory Mansions, though not quickly enough to prevent a swirl of gritty dust from entering along with him.\n\nThe hallway smelt of boiled cabbage and old rag mats. At one end of it a coloured poster, too large for indoor display, had been tacked to the wall. It depicted simply an enormous face, more than a metre wide: the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome features. Winston made for the stairs. It was no use trying the lift. Even at the best of times it was seldom working, and at present the electric current was cut off during daylight hours. It was part of the economy drive in preparation for Hate Week. The flat was seven flights up, and Winston, who was thirty-nine and had a varicose ulcer above his right ankle, went slowly, resting several times on the way. On each landing, opposite the lift-shaft, the poster with the enormous face gazed from the wall. It was one of those pictures which are so contrived that the eyes follow you about when you move. BIG BROTHER IS WATCHING YOU, the caption beneath it ran.\n\nInside the flat a fruity voice was reading out a list of figures which had something to do with the production of pig-iron. The voice came from an oblong metal plaque like a dulled mirror which formed part of the surface of the right-hand wall. Winston turned a switch and the voice sank somewhat, though the words were still distinguishable. The instrument (the telescreen, it was called) could be dimmed, but there was no way of shutting it off completely. He moved over to the window: a smallish, frail figure, the meagreness of his body merely emphasized by the blue overalls which were the uniform of the party. His hair was very fair, his face naturally sanguine, his skin roughened by coarse soap and blunt razor blades and the cold of the winter that had just ended.\n\nOutside, even through the shut window-pane, the world looked cold. Down in the street little eddies of wind were whirling dust and torn paper into spirals, and though the sun was shining and the sky a harsh blue, there seemed to be no colour in anything, except the posters that were plastered everywhere. The blackmoustachio'd face gazed down from every commanding corner. There was one on the house-front immediately opposite. BIG BROTHER IS WATCHING YOU, the caption said, while the dark eyes looked deep into Winston's own. Down at streetlevel another poster, torn at one corner, flapped fitfully in the wind, alternately covering and uncovering the single word INGSOC. In the far distance a helicopter skimmed down between the roofs, hovered for an instant like a bluebottle, and darted away again with a curving flight. It was the police patrol, snooping into people's windows. The patrols did not matter, however. Only the Thought Police mattered.\n\nBehind Winston's back the voice from the telescreen was still babbling away about pig-iron and the overfulfilment of the Ninth Three-Year Plan. The telescreen received and transmitted simultaneously. Any sound that Winston made, above the level of a very low whisper, would be picked up by it, moreover, so long as he remained within the field of vision which the metal plaque commanded, he could be seen as well as heard. There was of course no way of knowing whether you were being watched at any given moment. How often, or on what system, the Thought Police plugged in on any individual wire was guesswork. It was even conceivable that they watched everybody all the time. But at any rate they could plug in your wire whenever they wanted to. You had to live -- did live, from habit that became instinct -- in the assumption that every sound you made was overheard, and, except in darkness, every movement scrutinized.\n\nWinston kept his ...

# %% [markdown]
# # PDF Loader

# %%
from langchain_community.document_loaders.pdf import PyPDFLoader

# %%
file_name = "chapter_one.pdf"
file_path = os.path.join(base_path, file_name)

# %%
loader = PyPDFLoader(file_path)

# %%
docs = loader.load()

# %%
docs[0].page_content
# Out:
# "Part 1, Chapter 1 \n \n \nPart One \n \n \n1 \nIt was a bright cold day in April, and the clocks were striking thirteen. Winston Smith, his chin nuzzled \ninto his breast in an effort to escape the vile wind, slipped quickly through the glass doors of Victory \nMansions, though not quickly enough to prevent a swirl of gritty dust from entering along with him. \n \nThe hallway smelt of boiled cabbage and old rag mats. At one end of it a coloured poster, too large for \nindoor display, had been tacked to the wall. It depicted simply an enormous face, more than a metre \nwide: the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome \nfeatures. Winston made for the stairs. It was no use trying the lift. Even at the best of times it was \nseldom working, and at present the electric current was cut off during daylight hours. It was part of the \neconomy drive in preparation for Hate Week. The flat was seven flights up, and Winston, who was \nthirty-nine and had a varicose ulcer above his right ankle, went slowly, resting several times on the way. \nOn each landing, opposite the lift-shaft, the poster with the enormous face gazed from the wall. It was \none of those pictures which are so contrived that the eyes follow you about when you move. BIG \nBROTHER IS WATCHING YOU, the caption beneath it ran. \n \nInside the flat a fruity voice was reading out a list of figures which had something to do with the \nproduction of pig-iron. The voice came from an oblong metal plaque like a dulled mirror which formed \npart of the surface of the right-hand wall. Winston turned a switch and the voice sank somewhat, \nthough the words were still distinguishable. The instrument (the telescreen, it was called) could be \ndimmed, but there was no way of shutting it off completely. He moved over to the window: a smallish, \nfrail figure, the meagreness of his body merely emphasized by the blue overalls which were the \nuniform of the party. His hair was very fair, his face naturally sanguine, his skin roughened by coarse \nsoap and blunt razor blades and the cold of the winter that had just ended. \n \nOutside, even through the shut window-pane, the world looked cold. Down in the street little eddies of \nwind were whirling dust and torn paper into spirals, and though the sun was shining and the sky a \nharsh blue, there seemed to be no colour in anything, except the posters that were plastered \neverywhere. The blackmoustachio'd face gazed down from every commanding corner. There was one \non the house-front immediately opposite. BIG BROTHER IS WATCHING YOU, the caption said, while"

# %% [markdown]
# # UnstructuredFileLoader

# %%
from langchain_community.document_loaders import UnstructuredFileLoader

# %%
file_name = "chapter_one.docx"
file_path = os.path.join(base_path, file_name)

# %%
loader = UnstructuredFileLoader(file_path)
# Out:
# C:\Users\rbgir\AppData\Local\Temp\ipykernel_23400\1033047943.py:1: LangChainDeprecationWarning: The class `UnstructuredFileLoader` was deprecated in LangChain 0.2.8 and will be removed in 1.0. An updated version of the class exists in the `langchain-unstructured package and should be used instead. To use it run `pip install -U `langchain-unstructured` and import as `from `langchain_unstructured import UnstructuredLoader``.
#   loader = UnstructuredFileLoader(file_path)

# %%
docs = loader.load()

# %%
docs[0].page_content
# Out:
# "Part 1, Chapter 1\n\nPart One\n\n\n1\nIt was a bright cold day in April, and the clocks were striking thirteen. Winston Smith, his chin nuzzled into his breast in an effort to escape the vile wind, slipped quickly through the glass doors of Victory Mansions, though not quickly enough to prevent a swirl of gritty dust from entering along with him.\n\nThe hallway smelt of boiled cabbage and old rag mats. At one end of it a coloured poster, too large for indoor display, had been tacked to the wall. It depicted simply an enormous face, more than a metre wide: the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome features. Winston made for the stairs. It was no use trying the lift. Even at the best of times it was seldom working, and at present the electric current was cut off during daylight hours. It was part of the economy drive in preparation for Hate Week. The flat was seven flights up, and Winston, who was thirty-nine and had a varicose ulcer above his right ankle, went slowly, resting several times on the way. On each landing, opposite the lift-shaft, the poster with the enormous face gazed from the wall. It was one of those pictures which are so contrived that the eyes follow you about when you move. BIG BROTHER IS WATCHING YOU, the caption beneath it ran.\n\nInside the flat a fruity voice was reading out a list of figures which had something to do with the production of pig-iron. The voice came from an oblong metal plaque like a dulled mirror which formed part of the surface of the right-hand wall. Winston turned a switch and the voice sank somewhat, though the words were still distinguishable. The instrument (the telescreen, it was called) could be dimmed, but there was no way of shutting it off completely. He moved over to the window: a smallish, frail figure, the meagreness of his body merely emphasized by the blue overalls which were the uniform of the party. His hair was very fair, his face naturally sanguine, his skin roughened by coarse soap and blunt razor blades and the cold of the winter that had just ended.\n\n\n\n\n\nOutside, even through the shut window-pane, the world looked cold. Down in the street little eddies of wind were whirling dust and torn paper into spirals, and though the sun was shining and the sky a harsh blue, there seemed to be no colour in anything, except the posters that were plastered everywhere. The blackmoustachio'd face gazed down from every commanding corner. There was one on the house-front immediately opposite. BIG BROTHER IS WATCHING YOU, the caption said, while the dark eyes looked deep into Winston's own. Down at streetlevel another poster, torn at one corner, flapped fitfully in the wind, alternately covering and uncovering the single word INGSOC. In the far distance a helicopter skimmed down between the roofs, hovered for an instant like a bluebottle, and darted away again with a curving flight. It was the police patrol, snooping into people's windows. The patrols did not matter, however. Only the Thought Police mattered.\n\nBehind Winston's back the voice from the telescreen was still babbling away about pig-iron and the overfulfilment of the Ninth Three-Year Plan. The telescreen received and transmitted simultaneously. Any sound that Winston made, above the level of a very low whisper, would be picked up by it, moreover, so long as he remained within the field of vision which the metal plaque commanded, he could be seen as well as heard. There was of course no way of knowing whether you were being watched at any given moment. How often, or on what system, the Thought Police plugged in on any individual wire was guesswork. It was even conceivable that they watched everybody all the time. But at any rate they could plug in your wire whenever they wanted to. You had to live -- did live, from habit that became instinct -- in the assumption that every sound you made was overheard, and, except in darkness, every movement scrutinized.\n\nWinston ke ...

# %% [markdown]
# ## Splitter

# %%
from langchain_text_splitters.character import RecursiveCharacterTextSplitter

# %%
splitter = RecursiveCharacterTextSplitter()

# %%
# 들고온 문서를 splitter에게 전달하는 방법
# \n\n
documents = splitter.split_documents(docs)

# %%
print(len(documents))
# Out:
# 12

# %%
print(documents[0])
# Out:
# page_content='Part 1, Chapter 1
#
#
# Part One
#
#
# 1
# It was a bright cold day in April, and the clocks were striking thirteen. Winston Smith, his chin nuzzled
# into his breast in an effort to escape the vile wind, slipped quickly through the glass doors of Victory
# Mansions, though not quickly enough to prevent a swirl of gritty dust from entering along with him.
#
# The hallway smelt of boiled cabbage and old rag mats. At one end of it a coloured poster, too large for
# indoor display, had been tacked to the wall. It depicted simply an enormous face, more than a metre
# wide: the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome
# features. Winston made for the stairs. It was no use trying the lift. Even at the best of times it was
# seldom working, and at present the electric current was cut off during daylight hours. It was part of the
# economy drive in preparation for Hate Week. The flat was seven flights up, and Winston, who was
# thirty-nine and had a varicose ulcer above his right ankle, went slowly, resting several times on the way.
# On each landing, opposite the lift-shaft, the poster with the enormous face gazed from the wall. It was
# one of those pictures which are so contrived that the eyes follow you about when you move. BIG
# BROTHER IS WATCHING YOU, the caption beneath it ran.
#
# Inside the flat a fruity voice was reading out a list of figures which had something to do with the
# production of pig-iron. The voice came from an oblong metal plaque like a dulled mirror which formed
# part of the surface of the right-hand wall. Winston turned a switch and the voice sank somewhat,
# though the words were still distinguishable. The instrument (the telescreen, it was called) could be
# dimmed, but there was no way of shutting it off completely. He moved over to the window: a smallish,
# frail figure, the meagreness of his body merely emphasized by the blue overalls which were the
# uniform of the party. His hair was very fair, his face naturally sanguine, his skin roughened by coarse
# soap and blunt razor blades and the cold of the winter that had just ended.
#
# Outside, even through the shut window-pane, the world looked cold. Down in the street little eddies of
# wind were whirling dust and torn paper into spirals, and though the sun was shining and the sky a
# harsh blue, there seemed to be no colour in anything, except the posters that were plastered
# everywhere. The blackmoustachio'd face gazed down from every commanding corner. There was one
# on the house-front immediately opposite. BIG BROTHER IS WATCHING YOU, the caption said, while' metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2026-02-01T14:47:05+00:00', 'author': 'pagom4709@naver.com', 'moddate': '2026-02-01T14:47:05+00:00', 'source': 'C:\\back_0900_lgh\\python\\resource\\chapter_one.pdf', 'total_pages': 12, 'page': 0, 'page_label': '1'}

# %% [markdown]
# # chunk_size =
# - 모델의 context window가 크지 않은 경우 좀 더 작은 document로 분리해야하며, chunk_size의 값으로 크기를 조절할 수 있다.

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size = 200
)

# %%
# 문서를 들고올 때 잘라서 들고 오기
documents = loader.load_and_split(text_splitter = splitter)

# %%
print(len(documents))
# Out:
# 303

# %%
print(documents[1].page_content)
# Out:
# into his breast in an effort to escape the vile wind, slipped quickly through the glass doors of Victory

# %%
print(documents[2].page_content)
# Out:
# Mansions, though not quickly enough to prevent a swirl of gritty dust from entering along with him.

# %%
print(documents[3].page_content)
# Out:
# The hallway smelt of boiled cabbage and old rag mats. At one end of it a coloured poster, too large for

# %% [markdown]
# ## chunk_overlap=
# - 위와 같은 결과는 문장의 의미를 파괴할 수 있다. 작은 덩어리이면서 문장의 의미를 파괴하지 않는 방법이 chunk_overlap방법이다.
# - 앞 조각의 끝 부분을 조금 가져와서 다음 조각에게 연결시켜 겹치는 부분(오버레이)가 생길 수 있지만, 문맥이 자연스럽게 연결된다.

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size = 300,
    chunk_overlap = 100
)

# %%
# 문서를 들고올 때 잘라서 들고 오기
documents = loader.load_and_split(text_splitter = splitter)

# %%
print(documents[1].page_content)
# Out:
# Mansions, though not quickly enough to prevent a swirl of gritty dust from entering along with him.
#
# The hallway smelt of boiled cabbage and old rag mats. At one end of it a coloured poster, too large for

# %%
print(documents[2].page_content)
# Out:
# indoor display, had been tacked to the wall. It depicted simply an enormous face, more than a metre
# wide: the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome

# %%
print(documents[3].page_content)
# Out:
# wide: the face of a man of about forty-five, with a heavy black moustache and ruggedly handsome
# features. Winston made for the stairs. It was no use trying the lift. Even at the best of times it was

# %% [markdown]
# # Lucky Day

# %%
base_path = r"C:\back_0900_lgh\python\resource"

# %%
file_name = r"lucky_day.txt"
file_path = os.path.join(base_path, file_name)

# %%
loader = UnstructuredFileLoader(file_path)

# %%
loader.load()
# Out:
# libmagic is unavailable but assists in filetype detection. Please consider installing libmagic for better results.
# [Document(metadata={'source': 'C:\\back_0900_lgh\\python\\resource\\lucky_day.txt'}, page_content='운수 좋은 날 - 현진건\n\n새침하게 흐린 품이 눈이 올 듯하더니 눈은 아니 오고 얼다가 만 비가 추적추적 내리는 날이었다.\n\n이날이야말로 동소문 안에서 인력거꾼 노릇을 하는 김첨지에게는 오래간만에도 닥친 운수 좋은 날이었다 . 문안에(거기도 문밖은 아니지만) 들어간답시는 앞집 마마님을 전찻길까지 모셔다 드린 것을 비롯으로 행여나 손님이 있을까 하고 정류장에서 어정어정하며 내리는 사람 하나하나에게 거의 비는 듯한 눈결을 보내고 있다가 마침내 교원인 듯한 양복쟁이를 동광학교(東光學校)까지 태워다 주기로 되었다.\n\n첫 번에 삼십전 , 둘째 번에 오십전 - 아침 댓바람에 그리 흉치 않은 일이었다. 그야말로 재수가 옴붙어서 근 열흘 동안 돈 구경도 못한 김첨지는 십 전짜리 백동화 서 푼, 또는 다섯 푼이 찰깍 하고 손바닥에 떨어질 제 거의 눈물을 흘릴 만큼 기뻤었다. 더구나 이날 이때에 이 팔십 전이라는 돈이 그에게 얼마나 유용한지 몰랐다. 컬컬한 목에 모주 한 잔도 적실 수 있거니와 그보다도 앓는 아내에게 설렁탕 한 그릇도 사다 줄 수 있음이다.\n\n그의 아내가 기침으로 쿨룩거리기는 벌써 달포가 넘었다. 조밥도 굶기를 먹다시피 하는 형편이니 물론 약 한 첩 써본 일이 없다. 구태여 쓰려면 못쓸 바도 아니로되 그는 병이란 놈에게 약을 주어 보내면 재미를 붙여서 자꾸 온다는 자기의 신조(信條)에 어디까지 충실하였다. 따라서 의사에게 보인 적이 없으니 무슨 병인지는 알 수 없으되 반듯이 누워 가지고 일어나기는 새로 모로도 못 눕는 걸 보면 중증은 중증인 듯. 병이 이대도록 심해지기는 열흘전에 조밥을 먹고 체한 때문이다. 그때도 김첨지가 오래간만에 돈을 얻어서 좁쌀 한 되와 십 전짜리 나무 한 단을 사다 주었더니 김첨지의 말에 의지하면 그 오라질 년이 천방지축으로 냄비에 대고 끓였다. 마음은 급하고 불길은 달지 않아 채 익지도 않은 것을 그 오라질년이 숟가락은 고만두고 손으로 움켜서 두 뺨에 주먹덩이 같은 혹이 불거지도록 누가 빼앗을듯이 처박질하더니만 그날 저녁부터 가슴이 땡긴다, 배가 켕긴다고 눈을 흡뜨고 지랄병을 하였다. 그때 김첨지는 열화와 같이 성을 내며,\n\n“에이, 오라질년, 조랑복은 할 수가 없어, 못 먹어 병, 먹어서 병! 어쩌란 말이야! 왜 눈을 바루 뜨지 못해!”\n\n하고 앓는 이의 뺨을 한 번 후려갈겼다. 흡뜬 눈은 조금 바루어졌건만 이슬이 맺히었다. 김첨지의 눈시울도 뜨끈뜨끈하였다.\n\n이 환자가 그러고도 먹는 데는 물리지 않았다. 사흘 전부터 설렁탕 국물이 마시고 싶다고 남편을 졸랐다.\n\n“이런 오라질 년! 조밥도 못 먹는 년이 설렁탕은. 또 처먹고 지랄병을 하게.”\n\n라고, 야단을 쳐보았건만, 못 사주는 마음이 시원치는 않았다.\n\n인제 설렁탕을 사줄 수도 있다. 앓는 어미 곁에서 배고파 보채는 개똥이 (세살먹이)에게 죽을 사줄 수도 있다 - 팔십 전을 손에 쥔 김 첨지의 마음은 푼푼하였다.\n\n그러나 그의 행운은 그걸로 그치지 않았다. 땀과 빗물이 섞여 흐르는 목덜미를 기름주머니가 다된 왜목 수건으로 닦으며, 그 학교 문을 돌아 나올 때였다. 뒤에서 “인력거!” 하고 부르는 소리가 난다. 자기를 불러 멈춘 사람이 그 학교 학생인 줄 김첨지는 한번 보고 짐작할 수 있었다. 그 학생은 다짜고짜로,\n\n“남대문 정거장까지 얼마요.”\n\n라고 물었다. 아마도 그 학교 기숙사에 있는 이로 동기방학을 이용하여 귀향하려 함이리라. 오늘 가기로 작정은 하였건만 비는 오고, 짐은 있고 해서 어찌할 줄 모르다가 마침 김첨지를 보고 뛰어나왔음이리라. 그렇지 않으면왜 구두를 채 신지 못해서 질질 끌고, 비록 고구라 양복일망정 노박이로 비를 맞으며 김첨지를 뒤쫓아 나왔으랴.\n\n“남대문 정거장까지 말씀입니까.”\n\n하고 김첨지는 잠깐 주저하였다. 그는 이 우중에 우장도 없이 그 먼 곳을 철벅거리고 가기가 싫었음일까? 처음 것 둘째 것으로 고만 만족하였음일까? 아니다 결코 아니다. 이상하게도 꼬리를 맞물고 덤비는 이 행운 앞에 조금 겁이 났음이다. 그리고 집을 나올 제 아내의 부탁이 마음이 켕기었다 - 앞집 마마님한테서 부르러 왔을 제 병인은 뼈만 남은 얼굴에 유일의 샘물 같은 유달리 크고 움푹한 눈에 애걸하는 빛을 띄우며,\n\n“오늘은 나가지 말아요. 제발 덕분에 집에 붙어 있어요. 내가 이렇게 아픈데…….”\n\n라고, 모기 소리같이 중얼거리고 숨을 걸그렁걸그렁하였다. 그때에 김첨지는 대수롭지 않은듯이,\n\n“아따, 젠장맞을 년, 별 빌어먹을 소리를 다 하네. 맞붙들고 앉았으면 누가 먹여 살릴 줄 알아.”\n\n하고 훌쩍 뛰어나오려니까 환자는 붙잡을 듯이 팔을 내저으며,\n\n“나가지 말라도 그래, 그러면 일찍이 들어와요.”\n\n하고, 목메인 소리가 뒤를 따랐다.\n\n정거장까지 가잔 말을 들은 순간에 경련적으로 떠는 손 유달리 큼직한 눈울 듯한 아내의 얼굴이 김첨지의 눈앞에 어른어른하였다.\n\n“그래 남대문 정거장까지 얼마란 말이요?”\n\n하고 학생은 초조한 듯이 인력거꾼의 얼굴을 바라보며 혼자말같이,\n\n“인천 차가 열한 점에 있고 그 다음에는 새로 두 점이든가.”\n\n라고 중얼거린다.\n\n“일 원 오십 전만 줍시요.”\n\n이 말이 저도 모를 사이에 불쑥 김첨지의 입에서 떨어졌다. 제 입으로 부르고도 스스로 그 엄청난 돈 액수에 놀랐다. 한꺼번에 이런 금액을 불러라도 본 지가 그 얼마 만인가! 그러자 그 돈벌 용기가 병자에 대한 염려를 사르고 말았다. 설마 오늘 내로 어떠랴 싶었다. 무슨 일이 있더라도 제일 제이의 행운을 곱친 것보다고 오히려 갑절이 많은 이 행운을 놓칠 수 없다 하였다.\n\n“일 원 오십 전은 너무 과한데.”\n\n이런 말을 하며 학생은 고개를 기웃하였다.\n\n“아니올시다. 잇수로 치면 여기서 거기가 시오 리가 넘는답니다. 또 이런 진날은 좀 더 주셔야지요.”\n\n하고 빙글빙글 웃는 차부의 얼굴에는 숨길 수 없는 기쁨이 넘쳐흘렀다.\n\n“그러면 달라는 대로 줄 터이니 빨리 가요.”\n\n관대한 어린 손님은 이런 말을 남기고 총총히 옷도 입고 짐도 챙기러 갈 데로 갔다.\n\n그 학생을 태우고 나선 김첨지의 다리는 이상하게 거뿐하였다. 달음질을 한다느니보다 거의 나는 듯하였다. 바퀴도 어떻게 속히 도는지 구른다느니보다 마치 얼음을 지쳐 나가는 스케이트 모양으로 미끄러져 가는 듯하였다. 언 땅에 비가 내려 미끄럽기도 하였지만.\n\n이윽고 끄는 이의 다리는 무거워졌다. 자기 집 가까이 다다른 까닭이다. 새삼스러운 염려가 그의 가슴을 눌렀다. “오늘은 나가지 말아요, 내가 이렇게 아픈데” 이런 말이 잉잉 그의 귀에 울렸다. 그리고 병자의 움쑥 들어간 눈이 원망하는 듯이 자기를 노리는 듯하였다. 그러자 엉엉 하고 우는 개똥이의 곡성을 들은 듯싶다. 딸국딸국 하고 숨 모으는 소리도 나는 듯싶다.\n\n“왜 이리우, 기차 놓치겠구먼.”\n\n하고 탄 이의 초조한 부르짖음이 간신히 그의 귀에 들어왔다. 언뜻 깨달으니 김첨지는 인력거를 쥔 채 길 한복판에 엉거주춤 멈춰 있지 않은가.\n\n“예, 예.”\n\n하고, 김첨지는 또다시 달음질하였다. 집이 차차 멀어 갈수록 김첨지의 걸음에는 다시금 신이 나기 시작하였다. 다리를 재게 놀려야만 쉴새없이 자기의 머리에 떠오르는 모든 근심과 걱정을 잊을 듯이.\n\n정거장까지 끌어다 주고 그 깜짝 놀란 일 원 오십 전을 정말 제 손에 쥠에 제 말마따나 십리나 되는 길을 비를 맞아 가며 질퍽거리고 온 생각은 아니하고 거저나 얻은 듯이 고마웠다. 졸부나 된 듯이 기뻤다. 제 자식뻘밖에 안 되는 어린 손님에게 몇 번 허리를 굽히며,\n\n“안녕히 다녀옵시요.”\n\n라고 깍듯이 재우쳤다.\n\n그러나 빈 인력거를 털털거리며 이 우중에 돌아갈 일이 꿈밖이었다. 노동으로 하여 흐른 땀이 식어지자 굶주린 창자에서, 물 흐르는 옷에서 어슬어슬 한기가 솟아나기 비롯하매 일 원 오십 전이란 돈이 얼마나 괜찮고 괴로운 것인 줄 절절히 느끼었다. 정거장을 떠나는 그의 발길은 ...

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size=300,
    chunk_overlap = 100
)

# %%
documents = loader.load_and_split(text_splitter = splitter)
# Out:
# libmagic is unavailable but assists in filetype detection. Please consider installing libmagic for better results.

# %%
print(len(documents))
# Out:
# 51

# %%
documents[0].page_content
# Out:
# '운수 좋은 날 - 현진건\n\n새침하게 흐린 품이 눈이 올 듯하더니 눈은 아니 오고 얼다가 만 비가 추적추적 내리는 날이었다.\n\n이날이야말로 동소문 안에서 인력거꾼 노릇을 하는 김첨지에게는 오래간만에도 닥친 운수 좋은 날이었다 . 문안에(거기도 문밖은 아니지만) 들어간답시는 앞집 마마님을 전찻길까지 모셔다 드린 것을 비롯으로 행여나 손님이 있을까 하고 정류장에서 어정어정하며 내리는 사람 하나하나에게 거의 비는 듯한 눈결을 보내고 있다가 마침내 교원인 듯한 양복쟁이를 동광학교(東光學校)까지 태워다 주기로 되었다.'

# %%
documents[1].page_content
# Out:
# '첫 번에 삼십전 , 둘째 번에 오십전 - 아침 댓바람에 그리 흉치 않은 일이었다. 그야말로 재수가 옴붙어서 근 열흘 동안 돈 구경도 못한 김첨지는 십 전짜리 백동화 서 푼, 또는 다섯 푼이 찰깍 하고 손바닥에 떨어질 제 거의 눈물을 흘릴 만큼 기뻤었다. 더구나 이날 이때에 이 팔십 전이라는 돈이 그에게 얼마나 유용한지 몰랐다. 컬컬한 목에 모주 한 잔도 적실 수 있거니와 그보다도 앓는 아내에게 설렁탕 한 그릇도 사다 줄 수 있음이다.'

# %% [markdown]
# ## TikToken=
# - length_function=
# - OpenAI의 Chat 계열 모델이 텍스트를 처리하는 데 사용하는 토큰 단위(token)을 계산하고 변환하는 라이브러리
# - splitter의 len()가 length_fucntion의 default로 사용된다. 또한 CharacterTextSplitter에서는 "글자의 개수"를 chunk로 카운트한다.
# - 하지만 OpenAI에서는 token의 개수를 세므로 다르다. 따라서 맞춰줄 필요가 있다.

# %%
import tiktoken

# %%
from langchain_text_splitters.character import CharacterTextSplitter

# %%
splitter = CharacterTextSplitter(
    separator = "\n",
    chunk_size=300,
    chunk_overlap = 100,
    length_function = len 
)

# %%
len("abc")
# Out:
# 3

# %%
encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")

for i, doc in enumerate(documents):
    tokens = encoding.encode(doc.page_content)
    print(f"Chunk {i}: {len(tokens)} token")
# Out:
# Chunk 0: 296 token
# Chunk 1: 257 token
# Chunk 2: 309 token
# Chunk 3: 319 token
# Chunk 4: 135 token
# Chunk 5: 306 token
# Chunk 6: 178 token
# Chunk 7: 279 token
# Chunk 8: 230 token
# Chunk 9: 264 token
# Chunk 10: 252 token
# Chunk 11: 283 token
# Chunk 12: 287 token
# Chunk 13: 225 token
# Chunk 14: 235 token
# Chunk 15: 238 token
# Chunk 16: 235 token
# Chunk 17: 192 token
# Chunk 18: 248 token
# Chunk 19: 78 token
# Chunk 20: 296 token
# Chunk 21: 301 token
# Chunk 22: 142 token
# Chunk 23: 262 token
# Chunk 24: 257 token
# Chunk 25: 306 token
# Chunk 26: 312 token
# Chunk 27: 266 token
# Chunk 28: 258 token
# Chunk 29: 241 token
# Chunk 30: 144 token
# Chunk 31: 357 token
# Chunk 32: 266 token
# Chunk 33: 248 token
# Chunk 34: 302 token
# Chunk 35: 242 token
# Chunk 36: 280 token
# Chunk 37: 286 token
# Chunk 38: 185 token
# Chunk 39: 293 token
# Chunk 40: 315 token
# Chunk 41: 279 token
# Chunk 42: 294 token
# Chunk 43: 273 token
# Chunk 44: 317 token
# Chunk 45: 250 token
# Chunk 46: 302 token
# Chunk 47: 104 token
# Chunk 48: 278 token
# Chunk 49: 273 token
# Chunk 50: 280 token

# %% [markdown]
# ### chunk의 사이즈는 document의 길이를 기준으로 한다.
# ### ※따라서 token을 기준으로 바꿔주자

# %%
file_name = r"lucky_day.txt"
file_path = os.path.join(base_path, file_name)

loader = UnstructuredFileLoader(file_path)

splitter = CharacterTextSplitter.from_tiktoken_encoder(
    separator="\n",
    chunk_size=300,
    chunk_overlap=100,
)

documents = loader.load_and_split(text_splitter=splitter)
# Out:
# libmagic is unavailable but assists in filetype detection. Please consider installing libmagic for better results.
# Created a chunk of size 345, which is longer than the specified 300
# Created a chunk of size 315, which is longer than the specified 300
# Created a chunk of size 340, which is longer than the specified 300
# Created a chunk of size 356, which is longer than the specified 300
# Created a chunk of size 394, which is longer than the specified 300
# Created a chunk of size 425, which is longer than the specified 300
# Created a chunk of size 304, which is longer than the specified 300
# Created a chunk of size 421, which is longer than the specified 300
# Created a chunk of size 306, which is longer than the specified 300
# Created a chunk of size 428, which is longer than the specified 300
# Created a chunk of size 377, which is longer than the specified 300
# Created a chunk of size 432, which is longer than the specified 300
# Created a chunk of size 313, which is longer than the specified 300
# Created a chunk of size 374, which is longer than the specified 300
# Created a chunk of size 379, which is longer than the specified 300
# Created a chunk of size 320, which is longer than the specified 300
# Created a chunk of size 306, which is longer than the specified 300
# Created a chunk of size 303, which is longer than the specified 300
# Created a chunk of size 400, which is longer than the specified 300

# %%
encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")

for i, doc in enumerate(documents):
    tokens = encoding.encode(doc.page_content)
    print(f"Chunk {i}: {len(tokens)} token")
# Out:
# Chunk 0: 129 token
# Chunk 1: 167 token
# Chunk 2: 159 token
# Chunk 3: 97 token
# Chunk 4: 164 token
# Chunk 5: 113 token
# Chunk 6: 97 token
# Chunk 7: 180 token
# Chunk 8: 157 token
# Chunk 9: 150 token
# Chunk 10: 128 token
# Chunk 11: 169 token
# Chunk 12: 17 token
# Chunk 13: 192 token
# Chunk 14: 21 token
# Chunk 15: 133 token
# Chunk 16: 155 token
# Chunk 17: 102 token
# Chunk 18: 150 token
# Chunk 19: 124 token
# Chunk 20: 119 token
# Chunk 21: 212 token
# Chunk 22: 147 token
# Chunk 23: 125 token
# Chunk 24: 157 token
# Chunk 25: 217 token
# Chunk 26: 114 token
# Chunk 27: 127 token
# Chunk 28: 160 token
# Chunk 29: 32 token
# Chunk 30: 216 token
# Chunk 31: 78 token
# Chunk 32: 190 token
# Chunk 33: 191 token
# Chunk 34: 162 token
# Chunk 35: 121 token
# Chunk 36: 97 token
# Chunk 37: 60 token
# Chunk 38: 184 token
# Chunk 39: 135 token
# Chunk 40: 95 token
# Chunk 41: 77 token
# Chunk 42: 87 token
# Chunk 43: 120 token
# Chunk 44: 105 token
# Chunk 45: 84 token
# Chunk 46: 202 token
# Chunk 47: 56 token
# Chunk 48: 122 token
# Chunk 49: 144 token
# Chunk 50: 187 token
# Chunk 51: 155 token
# Chunk 52: 170 token
# Chunk 53: 159 token
# Chunk 54: 135 token
# Chunk 55: 163 token
# Chunk 56: 148 token
# Chunk 57: 140 token
# Chunk 58: 161 token
# Chunk 59: 149 token
# Chunk 60: 90 token
# Chunk 61: 113 token
# Chunk 62: 121 token
# Chunk 63: 134 token
# Chunk 64: 111 token
# Chunk 65: 72 token
# Chunk 66: 109 token
# Chunk 67: 123 token
# Chunk 68: 139 token
# Chunk 69: 129 token
# Chunk 70: 145 token
# Chunk 71: 100 token
# Chunk 72: 160 token
# Chunk 73: 148 token
# Chunk 74: 146 token
# Chunk 75: 121 token
# Chunk 76: 117 token
# Chunk 77: 219 token
# Chunk 78: 99 token
# Chunk 79: 111 token
# Chunk 80: 134 token
# Chunk 81: 104 token
# Chunk 82: 130 token
# Chunk 83: 99 token
# Chunk 84: 134 token
# Chunk 85: 168 token
# Chunk 86: 132 token
# Chunk 87: 67 token

# %% [markdown]
# ## 임베딩(embedding)과 벡터(Vector)
# ![](https://miro.medium.com/v2/resize:fit:2000/1*SYiW1MUZul1NvL1kc1RxwQ.png)

# %%
"""
Vectors
   - 방향과 크기를 가진 수치 데이터의 모음입니다.
   컴퓨터에서는 일반적으로 숫자 배열로 표현합니다

임베딩(Embedding)과 백터(Vector)
   - 임베딩은 사람이 읽는 텍스트를 컴퓨터가 이해(연산)할 수 있는
   숫자의 값으로 변환하는 작업이다.
   - 우리가 만든 Document마다 각각의 백터를 만들어 주게 될 것이다.
   - OpenAI는 크기가 최소 1000차원 이상의 백터를 제공해준다.

ex)
   3개의 차원을 정의해봅시다.

   첫 번째 차원 Masculinity(남성성)
   두 번째 차원 Femininity(여성성)
   세 번째 차원 Royalty(왕족스러움)

이제 특정 단어에 대한 차원 값(점수)를 줍시다.
    Masculinity Femininity Royalty
king     0.9       0.1       1.0
queen    0.1       0.9       1.0
man      0.9       0.1       0.0
woman    0.1       0.9       0.0

이렇게 3차원 백터의 점수를 매겨보았습니다.
단어를 이렇게 백터로 점수를 매기면 연산을 할 수 있습니다.
ex)
   king - man
   0.0      0.0      1.0
   즉 royal이 된다.

※단어를 숫자화(백터화)하면 의미에 대한 연산이 가능해진다.

Word2Vec
   - 신경망 기반의 자연어 처리(NLP) 기술로,단어를 고차원 공간의 밀집된 실수 벡터로 변환하여
   의미적 유사성을 포착하는 임베딩 기법입니다.
   - https://turbomaze.github.io/word2vecjson/
"""

None

# %% [markdown]
# # OpenAIEmbeddings
# - OpenAI 제공하고 있는 임베딩 모델

# %%
from langchain_openai.embeddings.base import OpenAIEmbeddings

# %%
embeddings = OpenAIEmbeddings()

# %%
vector = embeddings.embed_query("cat")

# %%
print(len(vector))
print(vector)
# Out:
# 1536
# [-0.0070539116859436035, -0.01734057068824768, -0.009698242880403996, -0.03073945827782154, -0.012484360486268997, 0.0030714645981788635, -0.005111427512019873, -0.041118279099464417, -0.014561542309820652, -0.021268075332045555, 0.019240519031882286, 0.05075980722904205, -0.0012246867408975959, 0.00255216914229095, -0.03845268115401268, -0.006057857070118189, 0.035475149750709534, -0.004622261971235275, 0.002374935196712613, -0.013455602340400219, -0.01894276589155197, 0.00905311107635498, 0.015894342213869095, -0.00870573241263628, -0.014731687493622303, 0.0071425288915634155, 0.013150759972631931, -0.013228743337094784, 0.0028676455840468407, 0.0048987469635903835, 0.004033844918012619, -0.016801780089735985, -0.015752553939819336, -0.04304658621549606, -0.027123885229229927, -0.004278427921235561, 0.008074779063463211, -0.009939280338585377, 0.022076262161135674, -0.009124004282057285, 0.004920014645904303, 0.00036133575486019254, -0.012073177844285965, 0.013200385496020317, -0.00380698568187654, 0.006990107707679272, -0.02209044061601162, -0.004480474628508091, 0.0013567260466516018, 0.013831338845193386, 0.002562803216278553, 0.008138583973050117, -0.011335884220898151, 0.010371731594204903, -0.005093703977763653, 0.0028144754469394684, 0.007996796630322933, -0.01271830964833498, 0.013136581517755985, 0.0022756841499358416, 0.01595105603337288, 0.004136640578508377, -0.0018467778572812676, 0.02275684103369713, 0.01121536549180746, -0.003401119727641344, -0.00725950300693512, 0.0004089673748239875, -0.004104738589376211, 0.005079525522887707, 0.03238419070839882, 0.028045503422617912, 0.02362174354493618, -0.005728201940655708, -0.009584812447428703, -0.0071496181190013885, -0.008663196116685867, 0.011357152834534645, -0.0006473470712080598, -0.005345376208424568, 0.035957228392362595, -0.032611049711704254, -0.016319703310728073, 0.005632495507597923, 0.019765131175518036, 0.006391056813299656, -0.009343774989247322, 0.00945720449090004, -0.010244122706353664, 0.010577322915196419, 0.02104121632874012, 0.026400770992040634, -0.01233548391610384, 0.037601958960294724, -0.01032919529825449, 0.019524093717336655, -0.016915209591388702, 0.02498289942741394, -0.006866043899208307, -0.05983418598771095, 0.005852265749126673, 0.005207133945077658, -0.04298986867070198, -0.007621060591191053, -0.0037467260845005512, -0.009138183668255806, 0.018474869430065155, 0.00099871342536062, 0.01755325123667717, -0.0026177456602454185, -0.0075005413964390755, 0.05750887840986252, 0.011860497295856476, -0.018205473199486732, 0.005958606023341417, -0.0052567594684660435, -0.004927104339003563, -0.024259785190224648, -0.006008231546729803, -0.015922699123620987, 0.010953059419989586, 0.009372131898999214, 0.038849685341119766, 0.007294950075447559, 0.018886052072048187, 0.01901366002857685, -0.007812472991645336, 0.013654104433953762, -0.013384709134697914, 0.017156247049570084, 0.02906637080013752, 0.0006349406903609633, 0.013909321278333664, 0.009747868403792381, 0.0009225027752108872, 0.027591783553361893, -0.0415152832865715, -0.0027701668441295624, -0.004778227768838406, -0.06278336048126221, -0.0023518947418779135, 0.01936812698841095, -0.0195382721722126, 0.015610767528414726, -0.010648217052221298, 0.023706814274191856, 0.024713503196835518, 0.003711279248818755, 0.012066088616847992, 0.0022898628376424313, 0.005210678558796644, -0.008996396325528622, 0.02715224400162697, -0.017609966918826103, -0.0073729329742491245, 0.030314097180962563, 0.0034578347112983465, 0.014916010200977325, -0.002132124500349164, -0.020091243088245392, -0.0002487921738065779, -0.004824308678507805, 0.016943566501140594, -0.014242521487176418, 0.005625405814498663, 0.02708134986460209, 0.02082853578031063, 0.004430849105119705, -0.013838428072631359, 0.00488456804305315, -0.019566629081964493, 0.022969521582126617, -0.006780971307307482, 0.007188609801232815, -0.003899147268384695, 0.00920907687395811, -0.0009100963943637908, -0.005196499638259411, -0.0132571 ...

# %% [markdown]
# # Chroma Vector Store

# %%
from langchain_community.vectorstores.chroma import Chroma
from langchain_text_splitters.character import CharacterTextSplitter
from langchain_community.document_loaders import UnstructuredFileLoader

# %%
splitter = CharacterTextSplitter.from_tiktoken_encoder(
    separator="\n",
    chunk_size=300,
    chunk_overlap=100,
)

docs = loader.load_and_split(text_splitter=splitter)

embeddings = OpenAIEmbeddings()

# 백터 스토어 생성
vector_store = Chroma.from_documents(docs, embeddings)
# Out:
# libmagic is unavailable but assists in filetype detection. Please consider installing libmagic for better results.
# Created a chunk of size 345, which is longer than the specified 300
# Created a chunk of size 315, which is longer than the specified 300
# Created a chunk of size 340, which is longer than the specified 300
# Created a chunk of size 356, which is longer than the specified 300
# Created a chunk of size 394, which is longer than the specified 300
# Created a chunk of size 425, which is longer than the specified 300
# Created a chunk of size 304, which is longer than the specified 300
# Created a chunk of size 421, which is longer than the specified 300
# Created a chunk of size 306, which is longer than the specified 300
# Created a chunk of size 428, which is longer than the specified 300
# Created a chunk of size 377, which is longer than the specified 300
# Created a chunk of size 432, which is longer than the specified 300
# Created a chunk of size 313, which is longer than the specified 300
# Created a chunk of size 374, which is longer than the specified 300
# Created a chunk of size 379, which is longer than the specified 300
# Created a chunk of size 320, which is longer than the specified 300
# Created a chunk of size 306, which is longer than the specified 300
# Created a chunk of size 303, which is longer than the specified 300
# Created a chunk of size 400, which is longer than the specified 300

# %%
len(docs)
# Out:
# 71

# %%
# 관계있는 문서를 가져옴
# llm이 판단해서 답변한 것이 아님

results = vector_store.similarity_search("김첨지의 직업은?")

# %%
results
# Out:
# [Document(metadata={'source': 'C:\\back_0900_lgh\\python\\resource\\lucky_day.txt'}, page_content='하여간 김첨지는 방문을 왈칵 열었다. 구역을 나게 하는 추기 ― 떨어진삿자리 밑에서 나온 먼지내 빨지 않은 기저귀에서 나는 똥내와 오줌내 가지각색 때가 켜켜이 앉은 옷내 병인의 땀 썩은 내가 섞인 추기가 무딘 김첨지의 코를 찔렀다.'),
#  Document(metadata={'source': 'C:\\back_0900_lgh\\python\\resource\\lucky_day.txt'}, page_content='김첨지는 취중에도 설렁탕을 사가지고 집에 다다랐다. 집이라 해도 물론셋집이요 또 집 전체를 세든 게 아니라 안과 뚝 떨어진 행랑방 한 간을 빌려 든 것인데 물을 길어 대고 한 달에 일 원씩 내는 터이다.'),
#  Document(metadata={'source': 'C:\\back_0900_lgh\\python\\resource\\lucky_day.txt'}, page_content='김첨지는 교묘하게도 정말 꾀꼬리 같은 소리를 내었다. 모든 사람은 일시에 웃었다.\n“빌어먹을 깍쟁이 같은 년, 누가 저를 어쩌나, ‘왜 남을 귀찮게 굴어!’ 어이구 소리가 처신도 없지, 허허.”'),
#  Document(metadata={'source': 'C:\\back_0900_lgh\\python\\resource\\lucky_day.txt'}, page_content='“아씨, 인력거 아니 타시랍시요.”\n그 여학생인지 만지가 한참은 매우 때깔을 빼며 입술을 꼭 다문 채 김첨지를 거들떠보지도 않았다. 김첨지는 구걸하는 거지나 무엇같이 연해연방 그의 기색을 살피며,')]

# %% [markdown]
# ## 임베딩 캐시(Embedding Cache)
# - 텍스트 데이터 수치형 벡터로 변환된 결과를 저장하고 동일한 입력이 들어왔을 때 계싼하지 않고,
# - 기존의 값을 재사용하는 기술을 의미합니다.

# %%
from langchain_classic.embeddings import CacheBackedEmbeddings
from langchain_classic.storage import LocalFileStore

# %%
# 없으면 자동 생성
cache_path = os.path.join(base_path, ".cahce")

cache_dir = LocalFileStore(cache_path)

cached_embeddings = CacheBackedEmbeddings.from_bytes_store(
    embeddings,
    cache_dir
)

vector_store = Chroma.from_documents(docs, cached_embeddings)

# %%
results = vector_store.similarity_search("김첨지의 직업은?")

# %% [markdown]
# # Retrieval

# %%
retrieval = vector_store.as_retriever()

# %% [markdown]
# # 생성 증강
# ## RetrievalQA
# 1) Stuff documents chain
#     * 모든 검색 문서를 한 번에 프롬프트에 “다 넣어서” 한 번에 답변 생성합니다
#     문서가 적을 때 빠르고 단순하지만, 길면 토큰 초과 위험 있습니다.
#     - 특징: 다 몰아서 한 번에
#
# 2) Refine documents chain
#     - 첫 문서로 1차 답변 생성 → 다음 문서로 점진적으로 답변 보완합니다.
#     문서가 많아도 안정적이지만 속도가 느립니다.
#     - 특징: 점진적 보완
#
# 3) Map reduce documents chain
#     - 각 문서마다 개별 답변 생성(Map)합니다. 그것들을 다시 종합(Reduce)합니다.
#     따라서 대용량 문서 처리에 적합니다.
#     - 특징: 나눠서 만들고 합침
#
# 4) Map re-rank documents chain
#     - 각 문서별로 답변 + 점수를 생성하고 가장 점수 높은 답변 선택합니다
#     "가장 관련성 높은 하나"를 뽑을 때 유리합니다.
#     - 특징: 점수 매겨서 최고만 선택

# %% [markdown]
# # 1. Stuff documnets chain

# %%
from langchain_text_splitters.character import CharacterTextSplitter
from langchain_community.document_loaders import UnstructuredFileLoader
from langchain_classic.storage import LocalFileStore
from langchain_classic.embeddings import CacheBackedEmbeddings
from langchain_openai.embeddings.base import OpenAIEmbeddings
from langchain_community.vectorstores.chroma import Chroma
from langchain_community.vectorstores.faiss import FAISS

from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough, RunnableLambda

# %% [markdown]
# ### 1. 파일 준비(loader)

# %%
base_path = r"C:\back_0900_lgh\python\resource"
file_name = "lucky_day.txt"

file_path = os.path.join(base_path, file_name)

loader = UnstructuredFileLoader(file_path)

# %% [markdown]
# ### 2. Splitter 준비 및 Split

# %%
splitter = CharacterTextSplitter.from_tiktoken_encoder(
    separator = "\n",
    chunk_size = 600,
    chunk_overlap=100
)

docs = loader.load_and_split(text_splitter = splitter)
# Out:
# libmagic is unavailable but assists in filetype detection. Please consider installing libmagic for better results.

# %%
len(docs)
# Out:
# 58

# %% [markdown]
# ### 3. 임베딩 모델, 임베딩 모델 캐싱, llm 준비

# %%
llm = ChatOpenAI(temperature=0)

cache_path = os.path.join(base_path, ".cache")

# 로컬 캐시 경로
cache_dir = LocalFileStore(cache_path)


# OpenAI의 임베딩 모델 객체
embeddings = OpenAIEmbeddings()


# 임베딩 모델을 캐싱(로컬에 저장)
cache_embeddings = CacheBackedEmbeddings.from_bytes_store(embeddings, cache_dir)

# %% [markdown]
# ## FAISS(파이스) vector store
# - Chroma 이외에 FAISS(Facebook AI Similarity Search) 백터 스토어도 존재합니다.
# - 페이스북에서 개발한 고속 벡터 검색 및 유사도 검색 라이브러리입니다.
# - 대량의 고차원 벡터 데이터를 빠르게 검색할 수 있도록 최적화 되어있습니다.
# - AI, 자연어 처리(NLP), 이미지 검색, 추천 시스템등에서 자주 사용됩니다.
# - FAISS(파이스)는 기본적으로 메모리에 만들어지지만, 파일의 형태로도 저장이 가능합니다.

# %% [markdown]
# ### 4. 벡터 스토어 생성, 리트리버 생성

# %%
# vector_store = Chroma.from_documents(docs, cache_embeddings)
vector_store = FAISS.from_documents(docs, cache_embeddings)

# 유사 문서를 검색하기 위한 리트리버 객체
retrieval = vector_store.as_retriever()

# %% [markdown]
# ### 5. 프롬프트 준비

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system","""
        **다음 문맥만 사용해서 질문에 답하세요.
        만약 추론할 수 있는 답변이 있다면 추론을 하고,
        답을 할 수 없다면, 답을 할 수 없다고 답하세요.
        
        문맥:
            {context}
    """),
    ("human","{question}"),
])

# %%
# List[Document] -> context:str
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# %%
chat = ChatOpenAI(temperature=0.1)

# %%
chain = {
    "context": retrieval | format_docs,
    "question": RunnablePassthrough()
} | prompt | chat

# %%
result = chain.invoke("김첨지의 직업이 뭐야?")

# %%
print(result.content)
# Out:
# 김첨지의 직업은 인력거꾼입니다.

# %% [markdown]
# # Refine Documents Chain

# %% [markdown]
# # 1. 파일 준비(loader)

# %%
file_name =r"lucky_day.txt"
file_path = os.path.join(base_path, file_path)


loader = UnstructuredFileLoader(file_path)

# %%
splitter = CharacterTextSplitter.from_tiktoken_encoder(
    separator = "\n",
    chunk_size = 600,
    chunk_overlap=100
)

docs = loader.load_and_split(text_splitter = splitter)
# Out:
# libmagic is unavailable but assists in filetype detection. Please consider installing libmagic for better results.

# %%
len(docs)
# Out:
# 47

# %% [markdown]
# ### 3. 임베딩 모델, 임베딩 캐싱, 벡터 스토어 생성, 리트리버 객체 생성

# %%
# 임베딩 모델
embeddings = OpenAIEmbeddings()

# 로컬 경로
cache_path = os.path.join(base_path, ".cache")
cache_dir = LocalFileStore(cache_path)

# 임베딩 캐싱
cached_embeddings = CacheBackedEmbeddings.from_bytes_store(embeddings, cache_dir)

# 벡터 스토어
vector_store = FAISS.from_documents(docs, cached_embeddings)

# 리트리버
retriever = vector_store.as_retriever()

# %% [markdown]
# ### 4. 프롬프트 작성

# %%
# 최초 프롬프트
initial_prompt = ChatPromptTemplate.from_template("""
    Given there following context:
    {context}

    Answer the question:
    {question}
""")

# refine 프롬프트
# refine_prompt = ChatPromptTemplate.from_template("""
#     당신의 임무는 최종 요약본을 작성하는 것입니다.
#     지금까지의 요약된 내용이 있습니다.
#     exsisting_answer:
#         {exsisting_answer}

#     이제 요약을 개선하는 데 도움이 될 수 있는 추가 context가 있습니다.
#     context:
#         {context}

#     새로운 context을 사용해서 원본을 요약하고 다듬습니다.
#     새로운 context에서 유용한 정보가 없다면, 원래 요약을 그대로 반환하세요.
# """)
refine_prompt = ChatPromptTemplate.from_template("""
    You are refining an existing summary with newly retrieved context.
    
    Current summary:
    {existing_answer}
    
    New context:
    {context}
    
    Instructions:
    - Update and improve the current summary using only relevant information from the new context.
    - Preserve important existing information unless contradicted by the new context.
    - Keep the summary concise, coherent, and non-redundant.
    - If the new context does not provide meaningful additional information, return the original summary unchanged.
    - Do not invent facts or include unsupported assumptions.
    
    Refined summary:
""")

# %%
docs[0]
# Out:
# Document(metadata={'source': 'C:\\back_0900_lgh\\python\\resource\\lucky_day.txt'}, page_content='운수 좋은 날 - 현진건\n새침하게 흐린 품이 눈이 올 듯하더니 눈은 아니 오고 얼다가 만 비가 추적추적 내리는 날이었다.\n이날이야말로 동소문 안에서 인력거꾼 노릇을 하는 김첨지에게는 오래간만에도 닥친 운수 좋은 날이었다 .')

# %%
def refine_docs(inputs):
    docs, question = inputs["docs"], inputs["question"]

    # 첫번째 문서로 시작
    chain = initial_prompt | chat
    result = chain.invoke({
        "context":docs[0].page_content,
        "question":question
    }).content

    # 두 번째 문서부터 refine 순회
    refine_chain = refine_prompt | chat
    for doc in docs[1:]:
        result = refine_chain.invoke({
            "exsisting_answer":result,
            "context" : doc.page_content,
            "question": question
        }).content

    return result

# %%
refine_chain = {
    "docs": retrieval,
    "question" : RunnablePassthrough()
} | RunnableLambda(refine_docs)

# %%
final_result = refine_chain.invoke("김천지가 먹은 음식은?")

# %%
final_result
# Out:
# '김첨지는 빈대떡 두 개와 추어탕을 먹은 후 두부와 미꾸리 국을 한 그릇을 먹었고, 막걸리 곱배기 두 잔을 마셨다. 이에 치삼이 의아해하며 돈이 사십 전이라고 말했다. 뚱뚱보는 말라깽이를 보던 맡에 부르짖었다. 그 목소리는 몸집과 딴판으로 연하고 싹싹하였다. 김첨지는 이 친구를 만난 게 어떻게 반가운지 몰랐다. 자기를 살려 준 은인이나 무엇같이 고맙기도 하였다. "자네는 벌써 한잔한 모양일세그려. 자네도 오늘 재미가 좋아 보이." 하고 김첨지는 얼굴을 펴서 웃었다. "아따, 재미 안 좋다고 술 못 먹을 낸가. 그런데 여보게, 자네 왼몸이 어째 물독에 빠진 새앙쥐 같은가. 어서 이리 들어와 말리게." 그 후에 "또 부어, 또 부어." 라고 외쳤다. 또 한 잔 먹고 나서 김첨지는 치삼의 어깨를 치며 문득 껄껄 웃는다. 그 웃음 소리가 어떻게 컸던지 술집에 있는 이의 눈은 모두 김첨지에게로 몰리었다. 웃는 이는 더욱 웃으며, “여보게 치삼이, 내 우스운 이야기 하나 할까. 오늘 손을 태고 정거장에 가지 않았겠나.” “그래서.” “갔다가 그저 오기가 안됐데그려. 그래 전차 정류장에서 어름어름하며 손님 하나를 태울 궁리를 하지 않았나."'

# %%
final_result = refine_chain.invoke("운수좋은 날의 엔딩은?")

# %%
final_result
# Out:
# '운수좋은 날의 엔딩은 김첨지에게는 오래간만에도 닥친 운수 좋은 날이었다고 나와 있습니다. 그러나 길 가는 사람들은 인력거꾼의 술 취한 상태를 걱정하며, 하늘이 어둡고 비가 오는 것을 보고 불길한 예감을 느끼는데, 이는 김첨지가 불행을 알게 될 때의 마음을 묘사하고 있다. 김첨지는 울음을 참으려고 하지만 목이 메어 울 수조차 없는 상태이며, 아내가 죽은 것을 알게 되어 충격을 받고 있다. 깍듯이 재우쳤던 안녕히 다녀옵시요의 말과 함께, 빈 인력거를 털털거리며 돌아가는 길은 꿈밖이었고, 굶주린 창자와 어슬어슬한기가 솟아나는 상황에서 돈의 가치를 깨닫게 되었다. 그의 발길은 힘 없이 온몸이 옹송그려지며 엎어져 못 일어날 것 같았다.'

# %% [markdown]
# # 3. Map reduce documents chain

# %% [markdown]
# ### 1. 파일 준비(loader)

# %%
file_name = r"heungbu.txt"
file_path = os.path.join(base_path, file_name)

loader = UnstructuredFileLoader(file_path)

# %% [markdown]
# ### 2. Splitter

# %%
splitter = CharacterTextSplitter.from_tiktoken_encoder(
    separator="\n",
    chunk_size = 600,
    chunk_overlap=100
)

docs = loader.load_and_split(text_splitter=splitter)
# Out:
# libmagic is unavailable but assists in filetype detection. Please consider installing libmagic for better results.

# %%
len(docs)
# Out:
# 75

# %% [markdown]
# ### 3. llm, embeddings, 캐시

# %%
chat = ChatOpenAI(temperature=0.5)

embeddings = OpenAIEmbeddings()

cache_path = os.path.join(base_path, ".cache")
cache_dir = LocalFileStore(cache_path)

# 캐싱된 embeddings 모델
cached_embeddings = CacheBackedEmbeddings.from_bytes_store(embeddings, cache_dir)

# %% [markdown]
# ### 4. 벡터 스토어, 리터리버

# %%
vector_store = FAISS.from_documents(docs, cached_embeddings)
retriever = vector_store.as_retriever()

# %% [markdown]
# ### 5. 프롬프트

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", """
        당신의 역할은 주어진 context에서 질문과 직접적으로 관련된 문장을 정확히 추출하는 것입니다.
        
        규칙:
            1. 질문과 관련된 문장이 있으면 원문을 수정하지 말고 그대로 반환하세요.
            2. 여러 문장이 관련되어 있다면 모두 반환하세요.
            3. 관련 없는 문장은 절대 포함하지 마세요.
            4. 요약, 해석, 설명, 추론, 재작성은 절대 하지 마세요.
            5. 관련 내용이 전혀 없으면 반드시 빈 문자열('')만 반환하세요.
            6. 출력에는 불필요한 말 없이 결과만 반환하세요.
            
        context:
            {context}
    """),
    ("human", "{question}"),
])

# %% [markdown]
# ### 6. chain 생성

# %%
map_reduce_chain = prompt | chat

# %%
def map_reduce(inputs):
    docs, question = inputs["docs"], inputs["question"]

    return "\n\n".join(
        map_reduce_chain.invoke({
            "context" : doc.page_content,
            "question" : question
        }).content
        for doc in docs
    )

# %%
map_chain = {
    "docs" : retriever,
    "question" : RunnablePassthrough()
} | RunnableLambda(map_reduce)

# %%
result = map_chain.invoke("다리가 뿌러진 새의 종류는?")

# %%
result
# Out:
# "''제비''\n\n''\n\n제비 새끼의 다리가 부러졌습니다.\n\n''''"

# %%
final_prompt = ChatPromptTemplate.from_messages([
    ("system","""
        다음 context의 따라 question에 답하세요.
        context:
            {context}
    """),
    ("human", "{question}")
])

# %%
final_chain = {
    "context":map_chain,
    "question": RunnablePassthrough()
} | final_prompt | chat

# %%
result = final_chain.invoke("다리가 부러진 새의 이름은?")

# %%
result.content
# Out:
# '제비'

# %%
result = final_chain.invoke("놀부는 어떻게 되었니?")

# %%
result.content
# Out:
# '놀부는 낫을 들고 동산으로 올라가서 돈이 없어서 죽는 도리밖에 없다고 생각했지만, 신의 부모가 흥부의 집에 깃들어 구조를 받아 살아났다. 그 후에 전답을 팔아 돈을 얻고 상두꾼들이 상여를 메고 갔다.'

# %%
result = final_chain.invoke("흥부는 부자가 되었니?")

# %%
result.content
# Out:
# '아니오, 흥부는 부자가 되지 않았습니다. 오히려 재산을 다 잃고 고생을 한 끝에 가난해지고 매를 맞고 어려움을 겪었던 것으로 나타납니다.'

# %% [markdown]
# # Map re-rank documents chain

# %%
import re

# %%
class MapReRankChain:
    def __init__(self, llm, retriever):
        self.llm = llm
        self.retriever = retriever

        # 1. 문서의 관련성 평가하는 프롬프트
        self.re_rank_prompt = ChatPromptTemplate.from_template("""
            다음 context의 질문과 얼마나 관련있는지
            0-10까지의 척도 내에서 숫자로만 대답하세요.
    
            context: 
                {context}
                
            question: 
                {question}
        """)
    
        self.final_prompt = ChatPromptTemplate.from_template("""
            아래 context에서 가장 관련성이 높은 정보를 바탕으로 question에 답하세요.
    
            context:
                {context}
                
            question:
                {question}
        """)
    
        self.re_rank_chain = self.re_rank_prompt | self.llm | StrOutputParser()
        self.final_chain = self.final_prompt | self.llm | StrOutputParser()

    # invoke 메서드 생성
    def invoke(self, question: str):
        docs = self.retriever.invoke(question)

        # re-rank 문서의 점수
        scored_docs = []
        for doc in docs:
            score_str = self.re_rank_chain.invoke({"context": doc.page_content, "question": question})

            # 숫자만 추출
            score = float(re.search(r"\d+", score_str).group()) if re.search(r"\d+", score_str) else 0
            scored_docs.append((score, doc))

        # 정렬 상위 k개
        scored_docs.sort(key=lambda tu: tu[0], reverse=True)
        top_docs = [doc for score, doc in scored_docs[:2]]
        
        print(f"재 정렬된 최고 점수: {scored_docs[0][0]}")

        # 최종 답변 생성
        context = "\n\n".join(doc.page_content for doc in top_docs)
        return self.final_chain.invoke({"context": context, "question": question})

# %%
re_rank_chain = MapReRankChain(llm=llm, retriever=retriever)

# %%
result = re_rank_chain.invoke("다리가 부러진 새는?")
# Out:
# 재 정렬된 최고 점수: 10.0

# %%
result
# Out:
# '제비입니다.'
