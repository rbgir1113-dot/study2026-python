# %%
score = int(input("점수를 입력하세요"))
# Out:
# 점수를 입력하세요 81

# %%
grade = ''

if score > 90 :
    grade = 'A'
elif score > 80 :
    grade = 'B'
elif score > 70 :
    grade = 'C'
else:
    grade = 'F'

print(grade)
# Out:
# B

# %%
"합격" if score > 60 else "불합격"
# Out:
# '합격'

# %%
if score % 2 == 0:
    print("짝수")
else:
    print("홀수")
# Out:
# 홀수
