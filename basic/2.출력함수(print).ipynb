# %%
# Ctrl + / : 주석
# "", '' : 구분하지 않는다
print('hello, world')
# Out:
# hello, world

# %%
print("'홍길동'님")
# Out:
# '홍길동'님

# %%
print("\'홍길동\'님")
# Out:
# '홍길동'님

# %%
print("a""b")
# Out:
# ab

# %%
print('c'"d")
# Out:
# cd

# %%
# doc string
print("""메롱 ^_^""")
# Out:
# 메롱 ^_^

# %%
print("""
      엔터 치고 싶으면 \' doc String을 사용해야 한다. \'
""")
# Out:
#       엔터 치고 싶으면 'doc String을 사용해야 한다. '

# %%
# 제어문자
# \n : 줄바꿈
# \t : 탭
# \' : '
# \" : "
# \\ : \

print("이름 : 홍길동 \n나이 : 20살")
# Out:
# 이름 : 홍길동
# 나이 : 20살

# %%
# print : 줄바꿈
print("홍길동", end ="")
print("안녕", end = "\n") # (default)
print("하세요", end = "")
# Out:
# 홍길동안녕
# 하세요

# %%
print("a", "b", "c", end = ", ")

# %%
# 파이썬은 키워드가 없다

a = 10
b = 10

# %%
#동적 바인딩 언어

print(type(a))
# Out:
# <class 'int'>

# %%
print(a)
# Out:
# 10

# %%
a = 20
print(a)
# Out:
# 20

# %%
# f"" : 포멧 "{}" 스트링
# `${}`
# 문자열 내부에서 변수를 사용할 수 있게 도와주는 문법
print(f"나이는 {a}살")
# Out:
# 나이는 20살

# %%
# r"" : 윈도우 환경에서 \ 또는 /를 경로로 정확히 인식시키기 위한 문"법
r"C:\back_0900_lgh\python\resource"
# Out:
# 'C:\\back_0900_lgh\\python\\resource'
