# %% [markdown]
# # 컬렉션(list, tuple, set, dict)
# 1. list []
#     - 추가, 수정, 삭제 언제나 가능
#     - [] 대괄호로 묶어주고 ,(콤마)로 값을 구분한다
#
# 2. tuple ()
#    - 한 번 생성되고나면 변경이 불가능
#    - () 소괄호로 묶어주고 ,(콤마)로 값을 구분한다
#
# 3. set {}
#    - 순서가 없는 자료 구조(비시퀀스)
#    - 중복된 값을 저장이 불가능
#    - {} 중괄호로 묶어주고 ,(콤마)로 값을 구분한다
#
# 4. dict {key:value}
#    - 키 + 값이 한 쌍으로 관리하며 ,(콤마)로 값을 구분한다
#    - key는 중복 값을 허용하지 않으며, value는 중복값을 허용한다
#    - key를 통해 value를 가져온다

# %%
li1 = []
li2 = list()

# %%
li2
# Out:
# []

# %%
li3 = [10,20,30,40,50]
li4 = [100,200,300,400,500]

# %%
print(li3)
print(li4)
# Out:
# [10, 20, 30, 40, 50]
# [100, 200, 300, 400, 500]

# %%
li3 + li4
# Out:
# [10, 20, 30, 40, 50, 100, 200, 300, 400, 500]

# %%
li3 * 2
# Out:
# [10, 20, 30, 40, 50, 10, 20, 30, 40, 50]

# %%
num = 10, 20, 30, 40

# %%
# 튜플 (packing)
print(num)
# Out:
# (10, 20, 30, 40)

# %%
# unpacking
one , two, three, four = num

# %%
one
# Out:
# 10

# %%
three
# Out:
# 30

# %%
str1 = ['a','b','c','d','e']

# %%
# 멤버쉽 연산자 (in) : 포함했다면 True, 아니라면 False
'd' in str1
# Out:
# True

# %%
"실수" if "." in "10.3" else "정수"
# Out:
# '실수'

# %%
str2 = "abcdef"

# %%
li5 = ['a','b','c','d','e']

# 참조 주소 변경
li5[0] = "A"

print(li5)
# Out:
# ['A', 'b', 'c', 'd', 'e']

# %%
# 튜플은 수정불가

tu1 = 'a', 'b', 'c'

tu1 = list(tu1)

tu1[0] = "A"
print(tu1[0])
# Out:
# A

# %%
names = '홍길동','장보고'

# %%
names * 2
# Out:
# ('홍길동', '장보고', '홍길동', '장보고')

# %%
names2 = ["홍길동", "장보고"]

# %%
# names + names2

# %%
names3 =  "김철수","김영희"

# %%
# 튜플끼리의 연결은 새로운 튜플이 생성됨
names + names3
# Out:
# ('홍길동', '장보고', '김철수', '김영희')

# %%
set1 = {'홍길동','멜론','기러기'}

# %%
# 인코딩 순서대로 나옴 , 다만 순서는 X

set1
# Out:
# {'기러기', '멜론', '홍길동'}

# %%
# set1 + {"장보고"}

# %% [markdown]
# # 딕셔너리

# %%
# default 값은 dict이다.
set1 = set()
di1 = dict()

# %%
print(type(set1))
print(type(di1))
# Out:
# <class 'set'>
# <class 'dict'>

# %%
di2 = {
    "a": "apple",
    "b": "banana",
    "c": "cherry",
    "a": "alpha"
}

# %%
di2
# Out:
# {'a': 'alpha', 'b': 'banana', 'c': 'cherry'}

# %%
b= "b"
di2[b]
di2["a"]

di2.get("c")
# Out:
# 'cherry'

# %%
# di2["d"]
# .get()으로 할시 에러는 발생 하지 않는다, 초기값 사용도 가능
di2.get("d", "없음")
# Out:
# '없음'

# %%
print(di2.keys())
print(di2.values())
print(di2.items()) # 튜플로 하나씩 가져옴

print(type(di2.keys()))
# Out:
# dict_keys(['a', 'b', 'c'])
# dict_values(['alpha', 'banana', 'cherry'])
# dict_items([('a', 'alpha'), ('b', 'banana'), ('c', 'cherry')])
# <class 'dict_keys'>
