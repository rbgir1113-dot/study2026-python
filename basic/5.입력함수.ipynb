# %%
name = input("이름을 입력하세요")
# Out:
# 이름을 입력하세요 홍길동

# %%
print(name)
# Out:
# 홍길동

# %%
num1= input("첫번째 정수를 입력하세요.")
num2= input("두번째 정수를 입력하세요.")
# Out:
# 첫번째 정수를 입력하세요. 1
# 두번째 정수를 입력하세요. 2

# %%
# 연결- > 연산
result = int(num1) + int(num2)
print(f"{result}")
# Out:
# 3
