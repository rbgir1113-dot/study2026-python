# %%
name = "홍길동"

# %%
name
# Out:
# '홍길동'

# %%
name = "장보고"

# %%
print(name)
# Out:
# 장보고

# %%
age = 20

# %%
print(name + 20)
# 1. 장보고20 - JS 처럼 자동 형변환 불가!
# 2. None 
# 3. 오류 - TypeError
# int + string X
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(name + 20)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# 숫자로 시작하면 안된다
123name = "홍길동"
# Out:
#   Cell In[13], line 2
#     123name = "홍길동"
#       ^
# SyntaxError: invalid decimal literal

# %%
!@문자열 = "홍길동"
# Out:
# '문자열'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
_name ="홍길동"

# %%
# 카멜 표기법 사용 불가
nAme = "홍길동"

# %%
# 공백문자 사용할수 없다
na me = "나미"
# Out:
#   Cell In[10], line 2
#     na me = "나미"
#        ^
# SyntaxError: invalid syntax

# %%
# 한글 변수명을 사용할 수 없다
이름 : "홍길동"

# %%
my_name = "홍길동"
